# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.20.1'

# %%
import pandas as pd

# %%
 pd.__version__
# Out:
# '1.2.4'

# %%
dhw=pd.read_csv('data_hw1.csv')

# %%
dhw
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
mean_list=dhw.groupby('Make').MSRP.mean()

# %%
mean_list.BMW
# Out:
# 61546.76347305389

# %%
subset_dhw=dhw[dhw['Year']>=2015]

# %%
subset_dhw
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
subset_dhw['Engine HP'].isnull().sum()
# Out:
# 51

# %%
mean_hp_before=dhw['Engine HP'].mean()

# %%
mean_hp_before
# Out:
# 249.38607007176023

# %%
ndhw=dhw['Engine HP'].fillna(mean_value)

# %%
ndhw
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
mean_hp_after=ndhw.mean()

# %%
mean_hp_after
# Out:
# 249.38607007176

# %%
print(round(mean_hp_before))
print(round(mean_hp_after))
# Out:
# 249
# 249

# %%
dhw['Make'] = dhw['Make'].str.replace('-', '_')

# %%
subset_Rolls_Royce=dhw[dhw.Make == 'Rolls_Royce']

# %%
subset_Rolls_Royce
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls_Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls_Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls_Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls_Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls_Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls_Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls_Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls_Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls_Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls_Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls_Royce                   Ghost  2014  premium unleaded (required)
# ...

# %%
subset_Rolls_Royce=subset_Rolls_Royce[['Engine HP', 'Engine Cylinders', 'highway MPG']]

# %%
subset_Rolls_Royce=subset_Rolls_Royce.drop_duplicates()

# %%
subset_Rolls_Royce
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X=subset_Rolls_Royce.values

# %%
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
XTX=(X.T).dot(X)

# %%
XTX_inv=np.linalg.inv(XTX)

# %%
XTX_inv.sum()
# Out:
# 0.03221232067748617

# %%
y = np.array([1000, 1100, 900, 1200, 1000, 850, 1300])

# %%
w=(XTX_inv.dot(X.T)).dot(y)

# %%
w[0]
# Out:
# 0.19989598183185642
